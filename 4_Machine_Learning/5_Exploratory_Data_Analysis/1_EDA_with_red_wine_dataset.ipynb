# %% [markdown]
# # Exploratory Data Analysis with the Red Wine Quality Dataset

# %% [markdown]
# **Description:**
#
# ![](./image/wines.jpg)
#
# This datasets is related to red variants of the Portuguese "Vinho Verde" wine.The dataset describes the amount of various chemicals present in wine and their effect on it's quality. The datasets can be viewed as classification or regression tasks. The classes are ordered and not balanced (e.g. there are much more normal wines than excellent or poor ones).Your task is to predict the quality of wine using the given data.
#
# A simple yet challenging project, to anticipate the quality of wine.
# The complexity arises due to the fact that the dataset has fewer samples, & is highly imbalanced.
# Can you overcome these obstacles & build a good predictive model to classify them?
#
# **This data frame contains the following columns:**
#
# **Input variables (based on physicochemical tests):**
# 1. fixed acidity
# 2. volatile acidity
# 3. citric acid
# 4. residual sugar
# 5. chlorides
# 6. free sulfur dioxide
# 7. total sulfur dioxide
# 8. density
# 9. pH
# 10. sulphates
# 11. alcohol
#
# **Output variable (based on sensory data):**
# 12 - quality (score between 0 and 10)
#
# **Acknowledgements:**
# - This dataset is also available from Kaggle & UCI machine learning repository, https://archive.ics.uci.edu/ml/datasets/wine+quality.
#
# Objective:
# - Understand the Dataset & cleanup (if required).
# - Build classification models to predict the wine quality.
# - Also fine-tune the hyperparameters & compare the evaluation metrics of various classification algorithms.

# %%
import pandas as pd

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv(r'./dataset/winequality-red.csv')
df
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# ...                                                 ...
# 1594  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5
# 1595  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...
# 1596  6.3;0.51;0.13;2.3;0.076;29;40;0.99574;3.42;0.7...
# 1597  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...
# 1598  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...
#
# [1599 rows x 1 columns]

# %% [markdown]
# ## Challenge 1st: set the DataFrame into it's correct format
#
# ![](./image/column_issue_first_challenge.png)

# %%
df = pd.read_csv(r'./dataset/winequality-red.csv', sep=";")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ## Challenge 2nd: Here we can observe some values where some extra zeros are there with the data after the decimal
# Let's remove those extra zeros
#
# ![](./image/column_issue_second_challenge.png)

# %%
df = pd.read_csv(r'./dataset/winequality-red.csv', sep=";", decimal=",")
df
# Out:
#      fixed acidity volatile acidity citric acid residual sugar chlorides  \
# 0              7.4              0.7           0            1.9     0.076
# 1              7.8             0.88           0            2.6     0.098
# 2              7.8             0.76        0.04            2.3     0.092
# 3             11.2             0.28        0.56            1.9     0.075
# 4              7.4              0.7           0            1.9     0.076
# ...            ...              ...         ...            ...       ...
# 1594           6.2              0.6        0.08              2      0.09
# 1595           5.9             0.55         0.1            2.2     0.062
# 1596           6.3             0.51        0.13            2.3     0.076
# 1597           5.9            0.645        0.12              2     0.075
# 1598             6             0.31        0.47            3.6     0.067
#
#      free sulfur dioxide total sulfur dioxide  density    pH sulphates  \
# ...

# %%
## Summary of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   object
#  1   volatile acidity      1599 non-null   object
#  2   citric acid           1599 non-null   object
#  3   residual sugar        1599 non-null   object
#  4   chlorides             1599 non-null   object
#  5   free sulfur dioxide   1599 non-null   object
#  6   total sulfur dioxide  1599 non-null   object
#  7   density               1599 non-null   object
#  8   pH                    1599 non-null   object
#  9   sulphates             1599 non-null   object
#  10  alcohol               1599 non-null   object
#  11  quality               1599 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 150.0+ KB

# %% [markdown]
# ### Observations:
#
# - The dataset consists of 1599 entries and 12 columns, with all columns containing 1599 non-null values.
#
# - The majority of the columns are classified as 'object' data type, indicating the need to convert these columns to numeric types for accurate analysis and modeling.
#
# - The 'quality' column is properly identified as having the 'int64' data type, making it suitable for use as the target variable in modeling or analysis.
#
#
# - It is crucial to convert the data type of the 'object' columns (fixed acidity, volatile acidity, citric acid, etc.) to numeric types (e.g., float). It can be achieved using the `pd.to_numeric` method.
#
# - Given that all columns show a non-null count of 1599, there are no obvious missing values in the dataset.

# %%
## Descriptive summary of the dataset

df.describe()
# Out:
#            quality
# count  1599.000000
# mean      5.636023
# std       0.807569
# min       3.000000
# 25%       5.000000
# 50%       6.000000
# 75%       6.000000
# max       8.000000

# %% [markdown]
# ### Observations:
# - The average quality rating of the wines in the dataset is approximately 5.64, suggesting potential for quality enhancement.
#
# - The standard deviation of 0.81 indicates consistent quality levels with moderate variability around the mean.
#
# - The majority of wines (75%) have quality ratings of 6 or lower, highlighting an opportunity for targeted quality improvement efforts.
#
# - Here, we can see that the summary regarding the `quality` column because the data type of the quality column is numeric.

# %% [markdown]
# ## Challenge 3rd: We have summary of only that column which have data type is of numeric and let's convert each column of dataset into numeric datatype
#
# ![](./image/column_issue_3rd_challenge.png)

# %%
# Convert each column in dataset to numeric column

for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
# Now, again check the descriptive summary of the dataset

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ### Observations:
#
# 1. The mean fixed acidity is approximately 8.32, and the standard deviation is relatively small at around 1.74, indicating moderate variability around the mean.
#
# 2. The mean alcohol content is approximately 10.42 with a small standard deviation of about 1.07, suggesting that the alcohol levels across the dataset are relatively consistent.
#
# 3. The quality column's range from 3 to 8, with the median (50th percentile) at 6, indicating a balanced distribution of quality ratings in the dataset.

# %%
# Shape of the dataset
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# - 1599 rows and 12 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
## List down all the columns

df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [markdown]
# - There are 6 unique values in the `quality` column which indicates that the "quality" feature in the wine dataset contains six unique values ranging from 3 to 8.
#
# -  The quality scores are distributed across a relatively narrow range, providing a clear overview of the quality variations present in the dataset.

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %% [markdown]
# -  The quality scores 5 and 6 are most prevalent in the dataset, with 681 and 638 occurrences respectively, indicating that the** majority of the wines** in the dataset **are of average quality**.
#
# -  The relatively small number of occurrences for quality scores 3, 4, 7, and 8 suggests a **skewed distribution**, with fewer instances of lower and higher quality wines compared to the average quality ones.
#
# - The distribution of quality scores 3, 4, 7, and 8 appears to be **relatively imbalanced** compared to the scores 5 and 6. Hence it is an **Imbalanced dataset**

# %%
## Missing values

df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# - There are no missing values in the dataset.

# %%
## To check duplicate/redundant records

df.duplicated().sum()
# Out:
# 240

# %% [markdown]
# - There are 240 duplicate/redundant records in the dataset.

# %%
## Show all duplicate records
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
## Remove the duplicated values

df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1359, 12)

# %% [markdown]
# - All the duplicated values in the dataset are remove completely from dataset of 1599 rows and now after removal it is just 1359 rows.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - Correlations are shown through the color levels and measured numbers in between.
#
# - For negative correlation the color is showing it is Black color.
#
# - Like fixed acidity column is negatively correlated with pH column and similarly with other features.

# %%
df['quality'].value_counts().plot(kind='bar', )
# Out:
# <Axes: xlabel='quality'>

# %%
sns.displot(df['fixed acidity'], kde=True)

# %%
for features in df.columns:
    # print(features)
    sns.displot(df[features], kde=True)

# %%
for features in df.columns:
    sns.histplot(df[features], kde=True)

# %%
## Categorical plot
sns.catplot(x='quality', y='alcohol', data=df, kind='box')

# %%
sns.scatterplot(x='alcohol', y='pH', hue='quality', data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>
